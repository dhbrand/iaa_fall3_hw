# %%
import pandas as pd
from auto_ml import Predictor

# %%
df_train = pd.read_csv("../data/train_data.csv")
df_valid = pd.read_csv("../data/valid_data.csv")

# %%
cat_cols = df_train.filter(regex=("cat*")).columns
column_descriptions = {'target': 'output'}
for col in cat_cols:
    column_descriptions[col] = 'categorical'

# %%
ml_predictor = Predictor(type_of_estimator='regressor', column_descriptions=column_descriptions)

# %%
ml_predictor.train(df_train, optimize_final_model=True, perform_feature_selection=True, cv=9)
# Out:
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at http://auto.ml
# You are running on version 2.9.9
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
# Running basic data cleaning
# Fitting DataFrameVectorizer
# Performing feature selection
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
#
#
# ********************************************************************************************
# Optimizing the hyperparameters for your model now
# About to run EvolutionaryAlgorithmSearchCV to find the optimal hyperparameters for the model GradientBoostingRegressor to predict target
# Population size each generation: 35
# Number of generations: 3
# Types [1, 1, 2, 2, 1, 1, 1] and maxint [0, 2, 4, 5, 7, 1, 9] detected
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58128>, model__max_features=log2, model__subsample=0.5, model__learning_rate=0.01, model__max_depth=15, model__loss=huber, model__n_estimators=50
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58390>, model__max_features=None, model__subsample=0.95, model__learning_rate=0.001, model__max_depth=1, model__loss=huber, model__n_estimators=100
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58208>, model__max_features=log2, model__subsample=0.8, model__learning_rate=0.01, model__max_depth=2, model__loss=huber, model__n_estimators=100
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a589e8>, model__max_features=None, model__subsample=0.65, model__learning_rate=0.001, model__max_depth=15, model__loss=huber, model__n_estimators=500
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# --- Evolve in 14400 possible combinations ---
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58dd8>, model__max_features=None, model__subsample=0.8, model__learning_rate=0.01, model__max_depth=5, model__loss=huber, model__n_estimators=150
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150
# [1] random_holdout_set_from_training_data's score is: -1.332
# [1] random_holdout_set_from_training_data's score is: -1.332
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58828>, model__max_features=None, model__subsample=0.65, model__learning_rate=0.01, model__max_depth=5, model__loss=ls, model__n_estimators=500
# [1] random_holdout_set_from_training_data's score is: -1.332
# [2] random_holdout_set_from_training_data's score is: -1.332
# [3] random_holdout_set_from_training_data's score is: -1.332
# [2] random_holdout_set_from_training_data's score is: -1.332
# [4] random_holdout_set_from_training_data's score is: -1.332
# [2] random_holdout_set_from_training_data's score is: -1.332
# [3] random_holdout_set_from_training_data's score is: -1.326
# [5] random_holdout_set_from_training_data's score is: -1.332
# [1] random_holdout_set_from_training_data's score is: -1.331
# [1] random_holdout_set_from_training_data's score is: -1.344
# [4] random_holdout_set_from_training_data's score is: -1.326
# [6] random_holdout_set_from_training_data's score is: -1.332
# [3] random_holdout_set_from_training_data's score is: -1.332
# [5] random_holdout_set_from_training_data's score is: -1.326
# [6] random_holdout_set_from_training_data's score is: -1.323
# [7] random_holdout_set_from_training_data's score is: -1.331
# [2] random_holdout_set_from_training_data's score is: -1.345
# [4] random_holdout_set_from_training_data's score is: -1.332
# [7] random_holdout_set_from_training_data's score is: -1.323
# [8] random_holdout_set_from_training_data's score is: -1.331
# [2] random_holdout_set_from_training_data's score is: -1.331
# [1] random_holdout_set_from_training_data's score is: -1.33
# [3] random_holdout_set_from_training_data's score is: -1.344
# [8] random_holdout_set_from_training_data's score is: -1.321
# [9] random_holdout_set_from_training_data's score is: -1.331
# [9] random_holdout_set_from_training_data's score is: -1.322
# [1] random_holdout_set_from_training_data's score is: -1.332
# [5] random_holdout_set_from_training_data's score is: -1.332
# [10] random_holdout_set_from_training_data's score is: -1.331
# [10] random_holdout_set_from_training_data's score is: -1.319
# [4] random_holdout_set_from_training_data's score is: -1.352
# [11] random_holdout_set_from_training_data's score is: -1.331
# [11] random_holdout_set_from_training_data's score is: -1.318
# [6] random_holdout_set_from_training_data's score is: -1.332
# [12] random_holdout_set_from_training_data's score is: -1.332
# [12] random_holdout_set_from_training_data's score is: -1.318
# [13] random_holdout_set_from_training_data's score is: -1.332
# [13] random_holdout_set_from_training_data's score is: -1.318
# [5] random_holdout_set_from_training_data's score is: -1.357
# [3] random_holdout_set_from_training_data's score is: -1.332
# [7] random_holdout_set_from_training_data's score is: -1.332
# [14] random_holdout_set_from_training_data's score is: -1.332
# [2] random_holdout_set_from_training_data's score is: -1.33
# [14] random_holdout_set_from_training_data's score is: -1.317
# [15] random_holdout_set_from_training_data's score is: -1.332
# [8] random_holdout_set_from_training_data's score is: -1.332
# [15] random_holdout_set_from_training_data's score is: -1.317
# [6] random_holdout_set_from_training_data's score is: -1.359
# [16] random_holdout_set_from_training_data's score is: -1.331
# [16] random_holdout_set_from_training_data's score is: -1.317
# [2] random_holdout_set_from_training_data's score is: -1.332
# [17] random_holdout_set_from_training_data's score is: -1.331
# [4] random_holdout_set_from_training_data's score is: -1.33
# [9] random_holdout_set_from_training_data's score is: -1.332
# [17] random_holdout_set_from_training_data's score is: -1.315
# [7] random_holdout_set_from_training_data's score is: -1.357
# [18] random_holdout_set_from_training_data's score is: -1.332
# [19] random_holdout_set_from_training_data's score is: -1.332
# [18] random_holdout_set_from_training_data's score is: -1.315
# [3] random_holdout_set_from_training_data's score is: -1.329
# [8] random_holdout_set_from_training_data's score is: -1.36
# [10] random_holdout_set_from_training_data's score is: -1.332
# [20] random_holdout_set_from_training_data's score is: -1.332
# [19] random_holdout_set_from_training_data's score is: -1.314
# [21] random_holdout_set_from_training_data's score is: -1.332
# [20] random_holdout_set_from_training_data's score is: -1.316
# [21] random_holdout_set_from_training_data's score is: -1.314
# [22] random_holdout_set_from_training_data's score is: -1.332
# [9] random_holdout_set_from_training_data's score is: -1.361
# [11] random_holdout_set_from_training_data's score is: -1.332
# [23] random_holdout_set_from_training_data's score is: -1.332
# [5] random_holdout_set_from_training_data's score is: -1.33
# [22] random_holdout_set_from_training_data's score is: -1.313
# [1] random_holdout_set_from_training_data's score is: -1.332
# [10] random_holdout_set_from_training_data's score is: -1.357
# [23] random_holdout_set_from_training_data's score is: -1.32
# [3] random_holdout_set_from_training_data's score is: -1.332
# [12] random_holdout_set_from_training_data's score is: -1.332
# [24] random_holdout_set_from_training_data's score is: -1.331
# [24] random_holdout_set_from_training_data's score is: -1.321
# [25] random_holdout_set_from_training_data's score is: -1.331
# [4] random_holdout_set_from_training_data's score is: -1.329
# [25] random_holdout_set_from_training_data's score is: -1.322
# [13] random_holdout_set_from_training_data's score is: -1.332
# [11] random_holdout_set_from_training_data's score is: -1.356
# [26] random_holdout_set_from_training_data's score is: -1.331
# [26] random_holdout_set_from_training_data's score is: -1.321
# [27] random_holdout_set_from_training_data's score is: -1.331
# [27] random_holdout_set_from_training_data's score is: -1.322
# [14] random_holdout_set_from_training_data's score is: -1.332
# [12] random_holdout_set_from_training_data's score is: -1.359
# [28] random_holdout_set_from_training_data's score is: -1.331
# [28] random_holdout_set_from_training_data's score is: -1.321
# [6] random_holdout_set_from_training_data's score is: -1.33
# [29] random_holdout_set_from_training_data's score is: -1.321
# [29] random_holdout_set_from_training_data's score is: -1.331
# [15] random_holdout_set_from_training_data's score is: -1.332
# [30] random_holdout_set_from_training_data's score is: -1.319
# [13] random_holdout_set_from_training_data's score is: -1.361
# [5] random_holdout_set_from_training_data's score is: -1.329
# [30] random_holdout_set_from_training_data's score is: -1.331
# [4] random_holdout_set_from_training_data's score is: -1.332
# [31] random_holdout_set_from_training_data's score is: -1.32
# [16] random_holdout_set_from_training_data's score is: -1.332
# [31] random_holdout_set_from_training_data's score is: -1.331
# [32] random_holdout_set_from_training_data's score is: -1.32
# [33] random_holdout_set_from_training_data's score is: -1.322
# [32] random_holdout_set_from_training_data's score is: -1.331
# [14] random_holdout_set_from_training_data's score is: -1.361
# [34] random_holdout_set_from_training_data's score is: -1.32
# [33] random_holdout_set_from_training_data's score is: -1.331
# [17] random_holdout_set_from_training_data's score is: -1.332
# [7] random_holdout_set_from_training_data's score is: -1.329
# [35] random_holdout_set_from_training_data's score is: -1.318
# [34] random_holdout_set_from_training_data's score is: -1.331
# [15] random_holdout_set_from_training_data's score is: -1.362
# [36] random_holdout_set_from_training_data's score is: -1.319
# [6] random_holdout_set_from_training_data's score is: -1.329
# [18] random_holdout_set_from_training_data's score is: -1.332
# [35] random_holdout_set_from_training_data's score is: -1.331
# [37] random_holdout_set_from_training_data's score is: -1.318
# [36] random_holdout_set_from_training_data's score is: -1.331
# [38] random_holdout_set_from_training_data's score is: -1.318
# [16] random_holdout_set_from_training_data's score is: -1.366
# [5] random_holdout_set_from_training_data's score is: -1.332
# [39] random_holdout_set_from_training_data's score is: -1.319
# [19] random_holdout_set_from_training_data's score is: -1.332
# [37] random_holdout_set_from_training_data's score is: -1.331
# [40] random_holdout_set_from_training_data's score is: -1.32
# [38] random_holdout_set_from_training_data's score is: -1.331
# [17] random_holdout_set_from_training_data's score is: -1.366
# [20] random_holdout_set_from_training_data's score is: -1.332
# [41] random_holdout_set_from_training_data's score is: -1.321
# [39] random_holdout_set_from_training_data's score is: -1.331
# [42] random_holdout_set_from_training_data's score is: -1.319
# [8] random_holdout_set_from_training_data's score is: -1.329
# The number of estimators that were the best for this training dataset: 22
# [18] random_holdout_set_from_training_data's score is: -1.368
# The best score on the holdout set: -1.3127866805230675
# [7] random_holdout_set_from_training_data's score is: -1.329
# [21] random_holdout_set_from_training_data's score is: -1.332
# [40] random_holdout_set_from_training_data's score is: -1.331
# [41] random_holdout_set_from_training_data's score is: -1.331
# [19] random_holdout_set_from_training_data's score is: -1.372
# [22] random_holdout_set_from_training_data's score is: -1.332
# [42] random_holdout_set_from_training_data's score is: -1.33
# [6] random_holdout_set_from_training_data's score is: -1.332
# [20] random_holdout_set_from_training_data's score is: -1.368
# [23] random_holdout_set_from_training_data's score is: -1.332
# [43] random_holdout_set_from_training_data's score is: -1.331
# [2] random_holdout_set_from_training_data's score is: -1.332
# [8] random_holdout_set_from_training_data's score is: -1.329
# [44] random_holdout_set_from_training_data's score is: -1.331
# [24] random_holdout_set_from_training_data's score is: -1.332
# [21] random_holdout_set_from_training_data's score is: -1.368
# [45] random_holdout_set_from_training_data's score is: -1.331
# [9] random_holdout_set_from_training_data's score is: -1.329
# [46] random_holdout_set_from_training_data's score is: -1.331
# [22] random_holdout_set_from_training_data's score is: -1.365
# [47] random_holdout_set_from_training_data's score is: -1.331
# [25] random_holdout_set_from_training_data's score is: -1.332
# [48] random_holdout_set_from_training_data's score is: -1.331
# [7] random_holdout_set_from_training_data's score is: -1.331
# [9] random_holdout_set_from_training_data's score is: -1.329
# [49] random_holdout_set_from_training_data's score is: -1.331
# [26] random_holdout_set_from_training_data's score is: -1.332
# [23] random_holdout_set_from_training_data's score is: -1.366
# The number of estimators that were the best for this training dataset: 3
# The best score on the holdout set: -1.3442856385203916
# [50] random_holdout_set_from_training_data's score is: -1.331
# [27] random_holdout_set_from_training_data's score is: -1.332
# [52] random_holdout_set_from_training_data's score is: -1.331
# [54] random_holdout_set_from_training_data's score is: -1.331
# [28] random_holdout_set_from_training_data's score is: -1.332
# [10] random_holdout_set_from_training_data's score is: -1.329
# [10] random_holdout_set_from_training_data's score is: -1.329
# [56] random_holdout_set_from_training_data's score is: -1.331
# [8] random_holdout_set_from_training_data's score is: -1.332
# [29] random_holdout_set_from_training_data's score is: -1.332
# [58] random_holdout_set_from_training_data's score is: -1.33
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000, score=-1.4134674547762665, total=   1.9s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# [30] random_holdout_set_from_training_data's score is: -1.332
# [1] random_holdout_set_from_training_data's score is: -1.35
# [60] random_holdout_set_from_training_data's score is: -1.33
# [2] random_holdout_set_from_training_data's score is: -1.347
# [31] random_holdout_set_from_training_data's score is: -1.332
# [11] random_holdout_set_from_training_data's score is: -1.329
# [3] random_holdout_set_from_training_data's score is: -1.357
# [62] random_holdout_set_from_training_data's score is: -1.33
# [11] random_holdout_set_from_training_data's score is: -1.328
# [4] random_holdout_set_from_training_data's score is: -1.356
# [32] random_holdout_set_from_training_data's score is: -1.332
# [5] random_holdout_set_from_training_data's score is: -1.361
# [9] random_holdout_set_from_training_data's score is: -1.332
# [3] random_holdout_set_from_training_data's score is: -1.332
# [6] random_holdout_set_from_training_data's score is: -1.361
# [64] random_holdout_set_from_training_data's score is: -1.33
# [7] random_holdout_set_from_training_data's score is: -1.356
# [33] random_holdout_set_from_training_data's score is: -1.332
# [8] random_holdout_set_from_training_data's score is: -1.355
# [66] random_holdout_set_from_training_data's score is: -1.33
# [9] random_holdout_set_from_training_data's score is: -1.354
# [12] random_holdout_set_from_training_data's score is: -1.327
# [12] random_holdout_set_from_training_data's score is: -1.329
# [34] random_holdout_set_from_training_data's score is: -1.332
# [10] random_holdout_set_from_training_data's score is: -1.358
# [11] random_holdout_set_from_training_data's score is: -1.362
# [68] random_holdout_set_from_training_data's score is: -1.329
# [12] random_holdout_set_from_training_data's score is: -1.362
# [13] random_holdout_set_from_training_data's score is: -1.354
# [35] random_holdout_set_from_training_data's score is: -1.332
# [70] random_holdout_set_from_training_data's score is: -1.329
# [14] random_holdout_set_from_training_data's score is: -1.356
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150, score=-1.4007829558548064, total=   2.2s
# [10] random_holdout_set_from_training_data's score is: -1.332
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150
# [13] random_holdout_set_from_training_data's score is: -1.326
# [15] random_holdout_set_from_training_data's score is: -1.354
# [72] random_holdout_set_from_training_data's score is: -1.329
# [36] random_holdout_set_from_training_data's score is: -1.332
# [16] random_holdout_set_from_training_data's score is: -1.354
# [13] random_holdout_set_from_training_data's score is: -1.329
# [17] random_holdout_set_from_training_data's score is: -1.354
# [1] random_holdout_set_from_training_data's score is: -1.518
# [74] random_holdout_set_from_training_data's score is: -1.329
# [18] random_holdout_set_from_training_data's score is: -1.354
# [37] random_holdout_set_from_training_data's score is: -1.332
# [19] random_holdout_set_from_training_data's score is: -1.354
# [76] random_holdout_set_from_training_data's score is: -1.329
# [2] random_holdout_set_from_training_data's score is: -1.525
# [20] random_holdout_set_from_training_data's score is: -1.354
# [38] random_holdout_set_from_training_data's score is: -1.332
# [21] random_holdout_set_from_training_data's score is: -1.349
# [22] random_holdout_set_from_training_data's score is: -1.349
# [78] random_holdout_set_from_training_data's score is: -1.329
# The number of estimators that were the best for this training dataset: 2
# The best score on the holdout set: -1.3472652053153185
# [11] random_holdout_set_from_training_data's score is: -1.332
# [3] random_holdout_set_from_training_data's score is: -1.528
# [14] random_holdout_set_from_training_data's score is: -1.329
# [39] random_holdout_set_from_training_data's score is: -1.332
# [80] random_holdout_set_from_training_data's score is: -1.329
# [4] random_holdout_set_from_training_data's score is: -1.523
# [14] random_holdout_set_from_training_data's score is: -1.326
# [40] random_holdout_set_from_training_data's score is: -1.332
# [5] random_holdout_set_from_training_data's score is: -1.526
# [82] random_holdout_set_from_training_data's score is: -1.329
# [41] random_holdout_set_from_training_data's score is: -1.332
# [15] random_holdout_set_from_training_data's score is: -1.329
# [6] random_holdout_set_from_training_data's score is: -1.531
# [84] random_holdout_set_from_training_data's score is: -1.329
# [42] random_holdout_set_from_training_data's score is: -1.332
# [12] random_holdout_set_from_training_data's score is: -1.332
# [15] random_holdout_set_from_training_data's score is: -1.326
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000, score=-1.4441580978678001, total=   0.8s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# [4] random_holdout_set_from_training_data's score is: -1.332
# [86] random_holdout_set_from_training_data's score is: -1.329
# [7] random_holdout_set_from_training_data's score is: -1.531
# [43] random_holdout_set_from_training_data's score is: -1.332
# [1] random_holdout_set_from_training_data's score is: -1.36
# [2] random_holdout_set_from_training_data's score is: -1.35
# [8] random_holdout_set_from_training_data's score is: -1.527
# [3] random_holdout_set_from_training_data's score is: -1.347
# [88] random_holdout_set_from_training_data's score is: -1.328
# [16] random_holdout_set_from_training_data's score is: -1.327
# [44] random_holdout_set_from_training_data's score is: -1.332
# [4] random_holdout_set_from_training_data's score is: -1.349
# [16] random_holdout_set_from_training_data's score is: -1.329
# [5] random_holdout_set_from_training_data's score is: -1.345
# [9] random_holdout_set_from_training_data's score is: -1.531
# [90] random_holdout_set_from_training_data's score is: -1.328
# [45] random_holdout_set_from_training_data's score is: -1.332
# [6] random_holdout_set_from_training_data's score is: -1.343
# [7] random_holdout_set_from_training_data's score is: -1.342
# [13] random_holdout_set_from_training_data's score is: -1.332
# [92] random_holdout_set_from_training_data's score is: -1.329
# [8] random_holdout_set_from_training_data's score is: -1.341
# [10] random_holdout_set_from_training_data's score is: -1.533
# [46] random_holdout_set_from_training_data's score is: -1.332
# [9] random_holdout_set_from_training_data's score is: -1.34
# [94] random_holdout_set_from_training_data's score is: -1.328
# [10] random_holdout_set_from_training_data's score is: -1.338
# [11] random_holdout_set_from_training_data's score is: -1.541
# [17] random_holdout_set_from_training_data's score is: -1.329
# [17] random_holdout_set_from_training_data's score is: -1.327
# [11] random_holdout_set_from_training_data's score is: -1.338
# [47] random_holdout_set_from_training_data's score is: -1.331
# [96] random_holdout_set_from_training_data's score is: -1.328
# [12] random_holdout_set_from_training_data's score is: -1.34
# [12] random_holdout_set_from_training_data's score is: -1.535
# [13] random_holdout_set_from_training_data's score is: -1.342
# [14] random_holdout_set_from_training_data's score is: -1.342
# [98] random_holdout_set_from_training_data's score is: -1.328
# [48] random_holdout_set_from_training_data's score is: -1.332
# [13] random_holdout_set_from_training_data's score is: -1.533
# [14] random_holdout_set_from_training_data's score is: -1.333
# [15] random_holdout_set_from_training_data's score is: -1.336
# [49] random_holdout_set_from_training_data's score is: -1.331
# [16] random_holdout_set_from_training_data's score is: -1.337
# [18] random_holdout_set_from_training_data's score is: -1.329
# [17] random_holdout_set_from_training_data's score is: -1.338
# [100] random_holdout_set_from_training_data's score is: -1.328
# [14] random_holdout_set_from_training_data's score is: -1.537
# [18] random_holdout_set_from_training_data's score is: -1.336
# [50] random_holdout_set_from_training_data's score is: -1.331
# [18] random_holdout_set_from_training_data's score is: -1.326
# [19] random_holdout_set_from_training_data's score is: -1.335
# [15] random_holdout_set_from_training_data's score is: -1.543
# [20] random_holdout_set_from_training_data's score is: -1.335
# [103] random_holdout_set_from_training_data's score is: -1.328
# [21] random_holdout_set_from_training_data's score is: -1.333
# [22] random_holdout_set_from_training_data's score is: -1.334
# [19] random_holdout_set_from_training_data's score is: -1.329
# [16] random_holdout_set_from_training_data's score is: -1.549
# [52] random_holdout_set_from_training_data's score is: -1.331
# [15] random_holdout_set_from_training_data's score is: -1.333
# [106] random_holdout_set_from_training_data's score is: -1.328
# [19] random_holdout_set_from_training_data's score is: -1.325
# [23] random_holdout_set_from_training_data's score is: -1.332
# [17] random_holdout_set_from_training_data's score is: -1.54
# [24] random_holdout_set_from_training_data's score is: -1.331
# [109] random_holdout_set_from_training_data's score is: -1.328
# [25] random_holdout_set_from_training_data's score is: -1.335
# [54] random_holdout_set_from_training_data's score is: -1.331
# [18] random_holdout_set_from_training_data's score is: -1.54
# [26] random_holdout_set_from_training_data's score is: -1.334
# [20] random_holdout_set_from_training_data's score is: -1.329
# [5] random_holdout_set_from_training_data's score is: -1.332
# [27] random_holdout_set_from_training_data's score is: -1.332
# [112] random_holdout_set_from_training_data's score is: -1.328
# [28] random_holdout_set_from_training_data's score is: -1.332
# [19] random_holdout_set_from_training_data's score is: -1.539
# [29] random_holdout_set_from_training_data's score is: -1.333
# [16] random_holdout_set_from_training_data's score is: -1.332
# [30] random_holdout_set_from_training_data's score is: -1.332
# [56] random_holdout_set_from_training_data's score is: -1.331
# [20] random_holdout_set_from_training_data's score is: -1.324
# [31] random_holdout_set_from_training_data's score is: -1.332
# [20] random_holdout_set_from_training_data's score is: -1.543
# [115] random_holdout_set_from_training_data's score is: -1.328
# [32] random_holdout_set_from_training_data's score is: -1.333
# [21] random_holdout_set_from_training_data's score is: -1.329
# [33] random_holdout_set_from_training_data's score is: -1.334
# [21] random_holdout_set_from_training_data's score is: -1.543
# [118] random_holdout_set_from_training_data's score is: -1.328
# The number of estimators that were the best for this training dataset: 1
# [58] random_holdout_set_from_training_data's score is: -1.331
# The best score on the holdout set: -1.517948461556245
# [34] random_holdout_set_from_training_data's score is: -1.333
# [35] random_holdout_set_from_training_data's score is: -1.334
# [36] random_holdout_set_from_training_data's score is: -1.334
# [17] random_holdout_set_from_training_data's score is: -1.332
# [21] random_holdout_set_from_training_data's score is: -1.323
# [37] random_holdout_set_from_training_data's score is: -1.332
# [60] random_holdout_set_from_training_data's score is: -1.331
# [38] random_holdout_set_from_training_data's score is: -1.332
# [121] random_holdout_set_from_training_data's score is: -1.327
# [39] random_holdout_set_from_training_data's score is: -1.332
# [22] random_holdout_set_from_training_data's score is: -1.33
# [40] random_holdout_set_from_training_data's score is: -1.331
# [41] random_holdout_set_from_training_data's score is: -1.331
# [62] random_holdout_set_from_training_data's score is: -1.331
# [124] random_holdout_set_from_training_data's score is: -1.327
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150, score=-1.456134968200127, total=   1.6s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150
# [42] random_holdout_set_from_training_data's score is: -1.333
# [43] random_holdout_set_from_training_data's score is: -1.335
# [127] random_holdout_set_from_training_data's score is: -1.327
# [44] random_holdout_set_from_training_data's score is: -1.332
# [18] random_holdout_set_from_training_data's score is: -1.332
# The number of estimators that were the best for this training dataset: 24
# The best score on the holdout set: -1.3306329104573205
# [23] random_holdout_set_from_training_data's score is: -1.329
# [22] random_holdout_set_from_training_data's score is: -1.323
# [1] random_holdout_set_from_training_data's score is: -1.44
# [64] random_holdout_set_from_training_data's score is: -1.331
# [130] random_holdout_set_from_training_data's score is: -1.327
# [2] random_holdout_set_from_training_data's score is: -1.443
# [6] random_holdout_set_from_training_data's score is: -1.332
# [66] random_holdout_set_from_training_data's score is: -1.331
# [3] random_holdout_set_from_training_data's score is: -1.438
# [133] random_holdout_set_from_training_data's score is: -1.327
# [24] random_holdout_set_from_training_data's score is: -1.329
# [19] random_holdout_set_from_training_data's score is: -1.332
# [4] random_holdout_set_from_training_data's score is: -1.441
# [23] random_holdout_set_from_training_data's score is: -1.323
# [136] random_holdout_set_from_training_data's score is: -1.327
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000, score=-1.339166511639774, total=   1.5s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# [5] random_holdout_set_from_training_data's score is: -1.437
# [68] random_holdout_set_from_training_data's score is: -1.331
# [1] random_holdout_set_from_training_data's score is: -1.353
# [139] random_holdout_set_from_training_data's score is: -1.327
# [2] random_holdout_set_from_training_data's score is: -1.356
# [3] random_holdout_set_from_training_data's score is: -1.36
# [25] random_holdout_set_from_training_data's score is: -1.329
# [6] random_holdout_set_from_training_data's score is: -1.437
# [4] random_holdout_set_from_training_data's score is: -1.354
# [142] random_holdout_set_from_training_data's score is: -1.328
# [24] random_holdout_set_from_training_data's score is: -1.323
# [5] random_holdout_set_from_training_data's score is: -1.354
# [70] random_holdout_set_from_training_data's score is: -1.331
# [7] random_holdout_set_from_training_data's score is: -1.439
# [6] random_holdout_set_from_training_data's score is: -1.347
# [20] random_holdout_set_from_training_data's score is: -1.333
# [7] random_holdout_set_from_training_data's score is: -1.347
# [145] random_holdout_set_from_training_data's score is: -1.327
# [8] random_holdout_set_from_training_data's score is: -1.438
# [8] random_holdout_set_from_training_data's score is: -1.336
# [9] random_holdout_set_from_training_data's score is: -1.335
# [72] random_holdout_set_from_training_data's score is: -1.331
# [148] random_holdout_set_from_training_data's score is: -1.327
# [10] random_holdout_set_from_training_data's score is: -1.332
# [26] random_holdout_set_from_training_data's score is: -1.329
# [9] random_holdout_set_from_training_data's score is: -1.439
# [11] random_holdout_set_from_training_data's score is: -1.336
# [25] random_holdout_set_from_training_data's score is: -1.324
# [12] random_holdout_set_from_training_data's score is: -1.337
# [13] random_holdout_set_from_training_data's score is: -1.333
# [10] random_holdout_set_from_training_data's score is: -1.438
# [74] random_holdout_set_from_training_data's score is: -1.331
# [14] random_holdout_set_from_training_data's score is: -1.333
# [15] random_holdout_set_from_training_data's score is: -1.334
# [151] random_holdout_set_from_training_data's score is: -1.327
# [21] random_holdout_set_from_training_data's score is: -1.332
# [11] random_holdout_set_from_training_data's score is: -1.438
# [16] random_holdout_set_from_training_data's score is: -1.332
# [17] random_holdout_set_from_training_data's score is: -1.327
# [27] random_holdout_set_from_training_data's score is: -1.328
# [154] random_holdout_set_from_training_data's score is: -1.327
# [12] random_holdout_set_from_training_data's score is: -1.439
# [76] random_holdout_set_from_training_data's score is: -1.331
# [18] random_holdout_set_from_training_data's score is: -1.325
# [19] random_holdout_set_from_training_data's score is: -1.325
# [26] random_holdout_set_from_training_data's score is: -1.323
# [13] random_holdout_set_from_training_data's score is: -1.438
# [157] random_holdout_set_from_training_data's score is: -1.327
# [20] random_holdout_set_from_training_data's score is: -1.329
# [7] random_holdout_set_from_training_data's score is: -1.332
# [21] random_holdout_set_from_training_data's score is: -1.332
# [22] random_holdout_set_from_training_data's score is: -1.332
# [14] random_holdout_set_from_training_data's score is: -1.44
# [22] random_holdout_set_from_training_data's score is: -1.332
# [78] random_holdout_set_from_training_data's score is: -1.331
# [160] random_holdout_set_from_training_data's score is: -1.327
# [23] random_holdout_set_from_training_data's score is: -1.335
# [28] random_holdout_set_from_training_data's score is: -1.329
# [24] random_holdout_set_from_training_data's score is: -1.34
# [15] random_holdout_set_from_training_data's score is: -1.44
# [25] random_holdout_set_from_training_data's score is: -1.342
# [26] random_holdout_set_from_training_data's score is: -1.347
# [27] random_holdout_set_from_training_data's score is: -1.344
# [27] random_holdout_set_from_training_data's score is: -1.323
# [80] random_holdout_set_from_training_data's score is: -1.331
# [28] random_holdout_set_from_training_data's score is: -1.343
# [16] random_holdout_set_from_training_data's score is: -1.45
# [163] random_holdout_set_from_training_data's score is: -1.327
# [29] random_holdout_set_from_training_data's score is: -1.343
# [30] random_holdout_set_from_training_data's score is: -1.345
# [29] random_holdout_set_from_training_data's score is: -1.329
# [17] random_holdout_set_from_training_data's score is: -1.453
# [31] random_holdout_set_from_training_data's score is: -1.342
# [23] random_holdout_set_from_training_data's score is: -1.332
# [82] random_holdout_set_from_training_data's score is: -1.331
# [32] random_holdout_set_from_training_data's score is: -1.342
# [18] random_holdout_set_from_training_data's score is: -1.454
# [28] random_holdout_set_from_training_data's score is: -1.323
# [33] random_holdout_set_from_training_data's score is: -1.342
# [166] random_holdout_set_from_training_data's score is: -1.327
# [34] random_holdout_set_from_training_data's score is: -1.34
# [35] random_holdout_set_from_training_data's score is: -1.34
# [19] random_holdout_set_from_training_data's score is: -1.456
# [84] random_holdout_set_from_training_data's score is: -1.331
# [36] random_holdout_set_from_training_data's score is: -1.342
# [30] random_holdout_set_from_training_data's score is: -1.329
# [169] random_holdout_set_from_training_data's score is: -1.327
# [37] random_holdout_set_from_training_data's score is: -1.342
# [20] random_holdout_set_from_training_data's score is: -1.459
# [38] random_holdout_set_from_training_data's score is: -1.343
# The number of estimators that were the best for this training dataset: 18
# The best score on the holdout set: -1.3246514753031249
# [24] random_holdout_set_from_training_data's score is: -1.332
# [172] random_holdout_set_from_training_data's score is: -1.327
# [86] random_holdout_set_from_training_data's score is: -1.331
# [29] random_holdout_set_from_training_data's score is: -1.323
# [21] random_holdout_set_from_training_data's score is: -1.46
# [175] random_holdout_set_from_training_data's score is: -1.327
# [31] random_holdout_set_from_training_data's score is: -1.329
# [22] random_holdout_set_from_training_data's score is: -1.464
# [8] random_holdout_set_from_training_data's score is: -1.332
# [88] random_holdout_set_from_training_data's score is: -1.331
# [178] random_holdout_set_from_training_data's score is: -1.327
# [23] random_holdout_set_from_training_data's score is: -1.467
# [25] random_holdout_set_from_training_data's score is: -1.331
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000, score=-1.5577430643090875, total=   1.2s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# [30] random_holdout_set_from_training_data's score is: -1.323
# [181] random_holdout_set_from_training_data's score is: -1.327
# [24] random_holdout_set_from_training_data's score is: -1.47
# [1] random_holdout_set_from_training_data's score is: -1.4
# [32] random_holdout_set_from_training_data's score is: -1.329
# [90] random_holdout_set_from_training_data's score is: -1.331
# [2] random_holdout_set_from_training_data's score is: -1.401
# [3] random_holdout_set_from_training_data's score is: -1.4
# [25] random_holdout_set_from_training_data's score is: -1.469
# The number of estimators that were the best for this training dataset: 5
# [184] random_holdout_set_from_training_data's score is: -1.327
# The best score on the holdout set: -1.4371259328634534
# [4] random_holdout_set_from_training_data's score is: -1.397
# [5] random_holdout_set_from_training_data's score is: -1.397
# [6] random_holdout_set_from_training_data's score is: -1.397
# [92] random_holdout_set_from_training_data's score is: -1.331
# [187] random_holdout_set_from_training_data's score is: -1.327
# [7] random_holdout_set_from_training_data's score is: -1.4
# [26] random_holdout_set_from_training_data's score is: -1.332
# [31] random_holdout_set_from_training_data's score is: -1.323
# [8] random_holdout_set_from_training_data's score is: -1.401
# [33] random_holdout_set_from_training_data's score is: -1.329
# [9] random_holdout_set_from_training_data's score is: -1.401
# [10] random_holdout_set_from_training_data's score is: -1.4
# [94] random_holdout_set_from_training_data's score is: -1.331
# [11] random_holdout_set_from_training_data's score is: -1.4
# [12] random_holdout_set_from_training_data's score is: -1.397
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150, score=-1.3347161228056064, total=   1.8s
# [190] random_holdout_set_from_training_data's score is: -1.327
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150
# [13] random_holdout_set_from_training_data's score is: -1.396
# [14] random_holdout_set_from_training_data's score is: -1.398
# [15] random_holdout_set_from_training_data's score is: -1.402
# [34] random_holdout_set_from_training_data's score is: -1.329
# [96] random_holdout_set_from_training_data's score is: -1.331
# [193] random_holdout_set_from_training_data's score is: -1.327
# [1] random_holdout_set_from_training_data's score is: -1.313
# [16] random_holdout_set_from_training_data's score is: -1.399
# [27] random_holdout_set_from_training_data's score is: -1.332
# The number of estimators that were the best for this training dataset: 7
# The best score on the holdout set: -1.3314238970105339
# [32] random_holdout_set_from_training_data's score is: -1.323
# [17] random_holdout_set_from_training_data's score is: -1.4
# [18] random_holdout_set_from_training_data's score is: -1.401
# [2] random_holdout_set_from_training_data's score is: -1.317
# [19] random_holdout_set_from_training_data's score is: -1.401
# [196] random_holdout_set_from_training_data's score is: -1.327
# [98] random_holdout_set_from_training_data's score is: -1.331
# [20] random_holdout_set_from_training_data's score is: -1.404
# [21] random_holdout_set_from_training_data's score is: -1.404
# [3] random_holdout_set_from_training_data's score is: -1.317
# [9] random_holdout_set_from_training_data's score is: -1.332
# [22] random_holdout_set_from_training_data's score is: -1.4
# [35] random_holdout_set_from_training_data's score is: -1.329
# [199] random_holdout_set_from_training_data's score is: -1.327
# [33] random_holdout_set_from_training_data's score is: -1.323
# [23] random_holdout_set_from_training_data's score is: -1.4
# [4] random_holdout_set_from_training_data's score is: -1.321
# [24] random_holdout_set_from_training_data's score is: -1.402
# [25] random_holdout_set_from_training_data's score is: -1.401
# [100] random_holdout_set_from_training_data's score is: -1.331
# [202] random_holdout_set_from_training_data's score is: -1.327
# [26] random_holdout_set_from_training_data's score is: -1.402
# [5] random_holdout_set_from_training_data's score is: -1.324
# [27] random_holdout_set_from_training_data's score is: -1.402
# [28] random_holdout_set_from_training_data's score is: -1.4
# [36] random_holdout_set_from_training_data's score is: -1.328
# [6] random_holdout_set_from_training_data's score is: -1.324
# [205] random_holdout_set_from_training_data's score is: -1.327
# [29] random_holdout_set_from_training_data's score is: -1.398
# [34] random_holdout_set_from_training_data's score is: -1.323
# [30] random_holdout_set_from_training_data's score is: -1.398
# [31] random_holdout_set_from_training_data's score is: -1.4
# [7] random_holdout_set_from_training_data's score is: -1.32
# [103] random_holdout_set_from_training_data's score is: -1.331
# [208] random_holdout_set_from_training_data's score is: -1.327
# [32] random_holdout_set_from_training_data's score is: -1.4
# [33] random_holdout_set_from_training_data's score is: -1.399
# The number of estimators that were the best for this training dataset: 13
# The best score on the holdout set: -1.3962113825278224
# [8] random_holdout_set_from_training_data's score is: -1.322
# [211] random_holdout_set_from_training_data's score is: -1.327
# [9] random_holdout_set_from_training_data's score is: -1.326
# [37] random_holdout_set_from_training_data's score is: -1.328
# [35] random_holdout_set_from_training_data's score is: -1.323
# [106] random_holdout_set_from_training_data's score is: -1.331
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58dd8>, model__max_features=None, model__subsample=0.8, model__learning_rate=0.01, model__max_depth=5, model__loss=huber, model__n_estimators=150, score=-1.3918867371730212, total=   6.4s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58dd8>, model__max_features=None, model__subsample=0.8, model__learning_rate=0.01, model__max_depth=5, model__loss=huber, model__n_estimators=150
# [10] random_holdout_set_from_training_data's score is: -1.325
# [214] random_holdout_set_from_training_data's score is: -1.327
# [11] random_holdout_set_from_training_data's score is: -1.322
# [217] random_holdout_set_from_training_data's score is: -1.327
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000, score=-1.4491502325908006, total=   1.1s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# [38] random_holdout_set_from_training_data's score is: -1.329
# [12] random_holdout_set_from_training_data's score is: -1.316
# [1] random_holdout_set_from_training_data's score is: -1.387
# [36] random_holdout_set_from_training_data's score is: -1.322
# [109] random_holdout_set_from_training_data's score is: -1.331
# [2] random_holdout_set_from_training_data's score is: -1.39
# [220] random_holdout_set_from_training_data's score is: -1.327
# [13] random_holdout_set_from_training_data's score is: -1.32
# [3] random_holdout_set_from_training_data's score is: -1.397
# [10] random_holdout_set_from_training_data's score is: -1.332
# [1] random_holdout_set_from_training_data's score is: -1.464
# [4] random_holdout_set_from_training_data's score is: -1.399
# [5] random_holdout_set_from_training_data's score is: -1.399
# [14] random_holdout_set_from_training_data's score is: -1.323
# [6] random_holdout_set_from_training_data's score is: -1.396
# [223] random_holdout_set_from_training_data's score is: -1.327
# [39] random_holdout_set_from_training_data's score is: -1.329
# [7] random_holdout_set_from_training_data's score is: -1.396
# [8] random_holdout_set_from_training_data's score is: -1.396
# [15] random_holdout_set_from_training_data's score is: -1.322
# [9] random_holdout_set_from_training_data's score is: -1.403
# [112] random_holdout_set_from_training_data's score is: -1.331
# [226] random_holdout_set_from_training_data's score is: -1.327
# [10] random_holdout_set_from_training_data's score is: -1.402
# [37] random_holdout_set_from_training_data's score is: -1.323
# [11] random_holdout_set_from_training_data's score is: -1.405
# [16] random_holdout_set_from_training_data's score is: -1.326
# [2] random_holdout_set_from_training_data's score is: -1.464
# [12] random_holdout_set_from_training_data's score is: -1.404
# [40] random_holdout_set_from_training_data's score is: -1.329
# [13] random_holdout_set_from_training_data's score is: -1.404
# [229] random_holdout_set_from_training_data's score is: -1.327
# [17] random_holdout_set_from_training_data's score is: -1.327
# [14] random_holdout_set_from_training_data's score is: -1.405
# [115] random_holdout_set_from_training_data's score is: -1.331
# [15] random_holdout_set_from_training_data's score is: -1.404
# [16] random_holdout_set_from_training_data's score is: -1.408
# [232] random_holdout_set_from_training_data's score is: -1.327
# [18] random_holdout_set_from_training_data's score is: -1.33
# [17] random_holdout_set_from_training_data's score is: -1.41
# [18] random_holdout_set_from_training_data's score is: -1.41
# [38] random_holdout_set_from_training_data's score is: -1.323
# [19] random_holdout_set_from_training_data's score is: -1.414
# [19] random_holdout_set_from_training_data's score is: -1.333
# [20] random_holdout_set_from_training_data's score is: -1.416
# [235] random_holdout_set_from_training_data's score is: -1.327
# [3] random_holdout_set_from_training_data's score is: -1.465
# [41] random_holdout_set_from_training_data's score is: -1.328
# [21] random_holdout_set_from_training_data's score is: -1.415
# The number of estimators that were the best for this training dataset: 1
# [118] random_holdout_set_from_training_data's score is: -1.331
# The best score on the holdout set: -1.3867020734252806
# [20] random_holdout_set_from_training_data's score is: -1.333
# [238] random_holdout_set_from_training_data's score is: -1.327
# [39] random_holdout_set_from_training_data's score is: -1.324
# [21] random_holdout_set_from_training_data's score is: -1.331
# The number of estimators that were the best for this training dataset: 1
# The best score on the holdout set: -1.3128728929332483
# [241] random_holdout_set_from_training_data's score is: -1.327
# [42] random_holdout_set_from_training_data's score is: -1.328
# [4] random_holdout_set_from_training_data's score is: -1.466
# [121] random_holdout_set_from_training_data's score is: -1.331
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000, score=-1.5539941187615298, total=   0.7s
# [CV] _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a58240>, model__max_features=log2, model__subsample=1.0, model__learning_rate=0.2, model__max_depth=2, model__loss=ls, model__n_estimators=1000
# [11] random_holdout_set_from_training_data's score is: -1.332
# [244] random_holdout_set_from_training_data's score is: -1.327
# [1] random_holdout_set_from_training_data's score is: -1.31
# [2] random_holdout_set_from_training_data's score is: -1.314
# [43] random_holdout_set_from_training_data's score is: -1.328
# [3] random_holdout_set_from_training_data's score is: -1.322
# [247] random_holdout_set_from_training_data's score is: -1.327
# [CV]  _scorer=<auto_ml.utils_scoring.RegressionScorer object at 0x1a30a586d8>, model__max_features=sqrt, model__subsample=0.65, model__learning_rate=0.1, model__max_depth=7, model__loss=huber, model__n_estimators=150, score=-1.5380556865206063, total=   1.6s
# ...
# |      -1.4191 |          0.0010 | ls     |          10 | log2           |            125 |      0.9500 |
# |      -1.4191 |          0.0500 | huber  |          10 |                |            200 |      0.9500 |
# |      -1.4191 |          0.1000 | ls     |           5 | log2           |            125 |      0.8000 |
# |      -1.4191 |          0.0010 | huber  |          10 |                |            500 |      0.6500 |
# |      -1.4191 |          0.0010 | ls     |          10 | log2           |            125 |      0.9500 |
# |      -1.4170 |          0.0100 | huber  |          10 |                |            125 |      0.6500 |
# |      -1.4170 |          0.0500 | huber  |           1 | log2           |            200 |      0.8000 |
# |      -1.4170 |          0.0500 | huber  |           1 | log2           |            125 |      0.9000 |
# |      -1.4170 |          0.0500 | huber  |           1 | sqrt           |            200 |      0.6500 |
# |      -1.4150 |          0.0010 | ls     |          15 | log2           |            125 |      0.9500 |
# +--------------+-----------------+--------+-------------+----------------+----------------+-------------+
# Now using the model training_params that you passed in:
# {'max_features': 'log2', 'learning_rate': 0.2, 'n_estimators': 500, 'subsample': 0.5, 'max_depth': 3, 'loss': 'ls'}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'max_features': 'log2', 'presort': False, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.2, 'warm_start': True, 'loss': 'ls', 'subsample': 0.5}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model GradientBoostingRegressor to predict target
# Started at:
# 2018-11-15 16:55:07
# [1] random_holdout_set_from_training_data's score is: -1.351
# [2] random_holdout_set_from_training_data's score is: -1.344
# [3] random_holdout_set_from_training_data's score is: -1.344
# [4] random_holdout_set_from_training_data's score is: -1.348
# [5] random_holdout_set_from_training_data's score is: -1.342
# [6] random_holdout_set_from_training_data's score is: -1.33
# [7] random_holdout_set_from_training_data's score is: -1.328
# [8] random_holdout_set_from_training_data's score is: -1.32
# [9] random_holdout_set_from_training_data's score is: -1.321
# [10] random_holdout_set_from_training_data's score is: -1.318
# [11] random_holdout_set_from_training_data's score is: -1.322
# [12] random_holdout_set_from_training_data's score is: -1.32
# [13] random_holdout_set_from_training_data's score is: -1.32
# [14] random_holdout_set_from_training_data's score is: -1.318
# [15] random_holdout_set_from_training_data's score is: -1.315
# [16] random_holdout_set_from_training_data's score is: -1.321
# [17] random_holdout_set_from_training_data's score is: -1.322
# [18] random_holdout_set_from_training_data's score is: -1.324
# [19] random_holdout_set_from_training_data's score is: -1.325
# [20] random_holdout_set_from_training_data's score is: -1.329
# [21] random_holdout_set_from_training_data's score is: -1.327
# [22] random_holdout_set_from_training_data's score is: -1.325
# [23] random_holdout_set_from_training_data's score is: -1.331
# [24] random_holdout_set_from_training_data's score is: -1.33
# [25] random_holdout_set_from_training_data's score is: -1.329
# [26] random_holdout_set_from_training_data's score is: -1.326
# [27] random_holdout_set_from_training_data's score is: -1.325
# [28] random_holdout_set_from_training_data's score is: -1.326
# [29] random_holdout_set_from_training_data's score is: -1.33
# [30] random_holdout_set_from_training_data's score is: -1.334
# [31] random_holdout_set_from_training_data's score is: -1.332
# [32] random_holdout_set_from_training_data's score is: -1.334
# [33] random_holdout_set_from_training_data's score is: -1.335
# [34] random_holdout_set_from_training_data's score is: -1.333
# [35] random_holdout_set_from_training_data's score is: -1.331
# The number of estimators that were the best for this training dataset: 15
# The best score on the holdout set: -1.315453153307347
# Finished training the pipeline!
# Total training time:
# 0:00:01
#
#
# Here are the results from our GradientBoostingRegressor
# predicting target
# Calculating feature responses, for advanced analytics.
# The printed list will only contain at most the top 100 features.
# +----+----------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
# |    | Feature Name   |   Importance |    Delta |   FR_Decrementing |   FR_Incrementing |   FRD_abs |   FRI_abs |   FRD_MAD |   FRI_MAD |
# |----+----------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------|
# |  0 | Unnamed: 0     |       0.0000 | 919.9382 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 64 | cat21=False    |       0.0000 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 33 | num33          |       0.0000 |  26.6477 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 17 | num17          |       0.0000 |   0.7834 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 35 | num35          |       0.0000 |   0.5467 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 15 | num15          |       0.0000 |   0.7977 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 43 | num44          |       0.0000 |   4.2226 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 44 | num45          |       0.0000 |   2.2513 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 12 | num12          |       0.0000 |   0.0345 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 10 | num10          |       0.0000 |   4.0758 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 48 | num49          |       0.0000 |   2.2500 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  8 | num8           |       0.0000 |   4.0887 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 59 | cat1=A         |       0.0000 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 60 | cat1=E         |       0.0000 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  4 | num4           |       0.0000 |   0.0058 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 61 | cat2=H         |       0.0000 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 62 | cat2=J         |       0.0000 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 63 | cat2=C         |       0.0000 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 56 | num57          |       0.0000 |  76.7571 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 24 | num24          |       0.0000 |   4.1844 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 58 | num59          |       0.0000 | 919.8211 |            0.0001 |           -0.0001 |    0.0001 |    0.0001 |    0.0000 |    0.0000 |
# | 26 | num26          |       0.0001 |   8.6364 |           -0.0000 |            0.0001 |    0.0000 |    0.0001 |    0.0000 |    0.0000 |
# | 34 | num34          |       0.0011 |  26.5347 |           -0.0003 |            0.0001 |    0.0003 |    0.0001 |    0.0000 |    0.0000 |
# | 32 | num32          |       0.0012 |   0.2455 |            0.0002 |           -0.0001 |    0.0002 |    0.0001 |    0.0000 |    0.0000 |
# | 11 | num11          |       0.0012 |   4.0621 |           -0.0001 |            0.0001 |    0.0001 |    0.0001 |    0.0000 |    0.0000 |
# | 14 | num14          |       0.0037 |   0.0569 |            0.0005 |           -0.0002 |    0.0005 |    0.0002 |    0.0000 |    0.0000 |
# | 65 | cat8=True      |       0.0038 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 55 | num56          |       0.0045 |   2.2500 |           -0.0003 |            0.0003 |    0.0003 |    0.0003 |    0.0000 |    0.0000 |
# | 37 | num38          |       0.0051 |  17.9140 |            0.0002 |           -0.0002 |    0.0002 |    0.0002 |    0.0000 |    0.0000 |
# | 19 | num19          |       0.0054 |   0.7109 |            0.0002 |           -0.0018 |    0.0002 |    0.0018 |    0.0000 |    0.0000 |
# | 40 | num41          |       0.0064 |   0.5467 |            0.0004 |           -0.0006 |    0.0004 |    0.0006 |    0.0000 |    0.0000 |
# | 41 | num42          |       0.0076 |  18.3723 |           -0.0007 |            0.0004 |    0.0007 |    0.0005 |    0.0000 |    0.0000 |
# | 46 | num47          |       0.0079 |  76.7681 |            0.0088 |           -0.0050 |    0.0092 |    0.0060 |    0.0000 |    0.0000 |
# | 45 | num46          |       0.0085 |   2.0393 |           -0.0007 |            0.0026 |    0.0007 |    0.0026 |    0.0000 |    0.0000 |
# | 38 | num39          |       0.0091 |   5.5331 |           -0.0214 |            0.0067 |    0.0214 |    0.0067 |    0.0000 |    0.0000 |
# | 29 | num29          |       0.0106 |   6.7246 |            0.0028 |           -0.0009 |    0.0028 |    0.0009 |    0.0000 |    0.0000 |
# | 25 | num25          |       0.0113 |   7.9282 |            0.0002 |           -0.0009 |    0.0002 |    0.0009 |    0.0000 |    0.0000 |
# | 13 | num13          |       0.0127 |   0.0475 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 30 | num30          |       0.0131 |  19.5508 |            0.0008 |           -0.0008 |    0.0008 |    0.0008 |    0.0000 |    0.0000 |
# | 39 | num40          |       0.0133 |   6.6850 |            0.0007 |           -0.0006 |    0.0007 |    0.0006 |    0.0000 |    0.0000 |
# | 23 | num23          |       0.0135 |   2.2769 |            0.0007 |           -0.0005 |    0.0007 |    0.0005 |    0.0000 |    0.0000 |
# | 49 | num50          |       0.0143 |  76.7571 |            0.0012 |           -0.0039 |    0.0012 |    0.0039 |    0.0000 |    0.0000 |
# | 36 | num37          |       0.0150 |  18.3793 |            0.0014 |           -0.0005 |    0.0014 |    0.0005 |    0.0000 |    0.0000 |
# | 50 | num51          |       0.0160 |   4.2226 |            0.0003 |           -0.0008 |    0.0003 |    0.0008 |    0.0000 |    0.0000 |
# | 16 | num16          |       0.0168 |   0.7858 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 27 | num27          |       0.0178 |   5.5294 |           -0.0080 |            0.0009 |    0.0080 |    0.0009 |    0.0000 |    0.0000 |
# | 54 | num55          |       0.0181 |  74.4318 |           -0.0004 |            0.0015 |    0.0004 |    0.0015 |    0.0000 |    0.0000 |
# | 18 | num18          |       0.0184 |   0.7165 |            0.0009 |            0.0000 |    0.0009 |    0.0000 |    0.0000 |    0.0000 |
# | 51 | num52          |       0.0207 |   2.2513 |            0.0007 |           -0.0014 |    0.0007 |    0.0014 |    0.0000 |    0.0000 |
# | 31 | num31          |       0.0211 |   0.5502 |            0.0017 |           -0.0028 |    0.0017 |    0.0028 |    0.0000 |    0.0000 |
# | 53 | num54          |       0.0251 |  76.7681 |            0.0036 |           -0.0045 |    0.0036 |    0.0045 |    0.0000 |    0.0000 |
# | 21 | num21          |       0.0264 |   0.7091 |            0.0003 |            0.0007 |    0.0016 |    0.0020 |    0.0000 |    0.0000 |
# | 52 | num53          |       0.0265 |   2.0393 |           -0.0019 |            0.0143 |    0.0019 |    0.0144 |    0.0000 |    0.0000 |
# | 20 | num20          |       0.0276 |   0.7161 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  3 | num3           |       0.0314 |   0.6974 |            0.0008 |           -0.0005 |    0.0008 |    0.0005 |    0.0000 |    0.0000 |
# |  5 | num5           |       0.0359 |   0.0079 |            0.0023 |           -0.0011 |    0.0023 |    0.0011 |    0.0000 |    0.0000 |
# |  9 | num9           |       0.0404 |   4.0730 |            0.0017 |           -0.0034 |    0.0021 |    0.0042 |    0.0000 |    0.0000 |
# | 42 | num43          |       0.0443 |   0.5782 |           -0.0001 |            0.0005 |    0.0027 |    0.0011 |    0.0000 |    0.0000 |
# |  1 | num1           |       0.0467 | 499.5119 |           -0.0015 |            0.0009 |    0.0015 |    0.0009 |    0.0000 |    0.0000 |
# | 22 | num22          |       0.0470 |   0.7174 |            0.0031 |           -0.0040 |    0.0031 |    0.0040 |    0.0000 |    0.0000 |
# | 28 | num28          |       0.0511 |   5.5592 |            0.0063 |           -0.0028 |    0.0063 |    0.0028 |    0.0000 |    0.0000 |
# | 47 | num48          |       0.0525 |  74.4318 |           -0.0040 |           -0.0005 |    0.0077 |    0.0108 |    0.0000 |    0.0000 |
# |  6 | num6           |       0.0586 |   0.0135 |            0.0003 |           -0.0016 |    0.0003 |    0.0016 |    0.0000 |    0.0000 |
# |  7 | num7           |       0.0596 |   0.0182 |            0.0135 |           -0.0055 |    0.0148 |    0.0094 |    0.0000 |    0.0000 |
# |  2 | num2           |       0.0639 |   4.0834 |           -0.0051 |            0.0091 |    0.0069 |    0.0130 |    0.0000 |    0.0000 |
# | 57 | num58          |       0.0647 |   0.7091 |            0.0006 |           -0.0005 |    0.0006 |    0.0005 |    0.0000 |    0.0000 |
# +----+----------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
#
#
# *******
# Legend:
# Importance = Feature Importance
#      Explanation: A weighted measure of how much of the variance the model is able to explain is due to this column
# FR_delta = Feature Response Delta Amount
#      Explanation: Amount this column was incremented or decremented by to calculate the feature reponses
# FR_Decrementing = Feature Response From Decrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to subtracting one FR_delta amount from every value in this column
# FR_Incrementing = Feature Response From Incrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to adding one FR_delta amount to every value in this column
# FRD_MAD = Feature Response From Decrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if decrementing this feature provokes strong changes that are both positive and negative
# FRI_MAD = Feature Response From Incrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if incrementing this feature provokes strong changes that are both positive and negative
# FRD_abs = Feature Response From Decrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to subtracting one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# FRI_abs = Feature Response From Incrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to adding one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# *******

# %%
test_score = ml_predictor.score(df_valid, df_valid.target)
# Out:
# None
#
#
# ***********************************************
# Advanced scoring metrics for the trained regression model on this particular dataset:
#
# Here is the overall RMSE for these predictions:
# 1.4148614520307667
#
# Here is the average of the predictions:
# 20.03717979591026
#
# Here is the average actual value on this validation set:
# 20.024082777165344
#
# Here is the median prediction:
# 20.035501623752527
#
# Here is the median actual value:
# 20.040008
#
# Here is the mean absolute error:
# 0.9668935376190846
#
# Here is the median absolute error (robust to outliers):
# 0.615000499999999
#
# Here is the explained variance:
# -0.002484701826392266
#
# Here is the R-squared value:
# -0.002570609515842426
# Count of positive differences (prediction > actual):
# 636
# Count of negative differences:
# 634
# Average positive difference:
# 0.9784496907096575
# Average negative difference:
# -0.9553009297869015
#
#
# ***********************************************

# %%
from sklearn.ensemble import GradientBoostingRegressor as GBM
from sklearn.metrics import mean_absolute_error as mae

# %%
train = pd.read_csv("../data/train_data.csv")
valid = pd.read_csv("../data/valid_data.csv")

# %%
X_train = train.drop('target', axis=1)
y_train = train.target

X_test = valid.drop('target', axis=1)
y_test = valid.target

# %%
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
params = {'max_features': 'log2', 'learning_rate': 0.2, 'subsample': 0.5, 'max_depth': 3, 
 'loss': 'ls', 'n_estimators': 15, 'random_state': 999}

# %%
mod = GBM(**params)

# %%
mod.fit(X_train, y_train)
y_pred = mod.predict(X_test)
mae(y_test, y_pred)
# Out:
# 0.9677727908775298

# %%
x_holdout = pd.read_csv('../data/testData.csv')

# %%
x_holdout.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
print(np.sort(X_train.cat2.unique()))
print(np.sort(x_holdout.cat2.unique()))
# Out:
# ['A' 'B' 'C' 'D' 'E' 'F' 'G' 'H' 'I' 'J' 'K' 'L']
# ['G' 'H' 'I' 'J']

# %%
X_train.columns
# Out:
# Index(['num1', 'num2', 'num3', 'num4', 'num5', 'num6', 'num7', 'num8', 'num9',
#        'num10', 'num11', 'num12', 'num13', 'num14', 'num15', 'num16', 'num17',
#        'num18', 'num19', 'num20', 'num21', 'num22', 'num23', 'num24', 'num25',
#        'num26', 'num27', 'num28', 'num29', 'num30', 'num31', 'num32', 'num33',
#        'num34', 'num35', 'num36', 'num37', 'num38', 'num39', 'num40', 'num41',
#        'num42', 'num43', 'num44', 'num45', 'num46', 'num47', 'num48', 'num49',
#        'num50', 'num51', 'num52', 'num53', 'num54', 'num55', 'num56', 'num57',
#        'num58', 'num59', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9', 'cat10', 'cat11', 'cat12', 'cat13', 'cat14', 'cat15', 'cat16',
#        'cat17', 'cat18', 'cat19', 'cat20', 'cat21', 'cat22', 'cat23', 'cat24',
#        'cat25', 'cat26', 'cat1_A', 'cat1_B', 'cat1_C', 'cat1_D', 'cat1_E',
#        'cat2_A', 'cat2_B', 'cat2_C', 'cat2_D', 'cat2_E', 'cat2_F', 'cat2_G',
#        'cat2_H', 'cat2_I', 'cat2_J', 'cat2_K', 'cat2_L'],
#       dtype='object')

# %% [markdown]
# need to create missing columns for A, B, C, D, E, F, K, L

# %%
x_holdout = pd.get_dummies(x_holdout)

# %%
missing_columns = ['A', 'B', 'C', 'D', 'E', 'F', 'K', 'L']
n = x_holdout.shape[0]

# %%
for col in missing_columns:
    col_name = 'cat2_' + col
    x_holdout[col_name] = np.repeat(0, n)

# %%
print(x_holdout.columns)
print(x_holdout.shape)
# Out:
# Index(['num1', 'num2', 'num3', 'num4', 'num5', 'num6', 'num7', 'num8', 'num9',
#        'num10', 'num11', 'num12', 'num13', 'num14', 'num15', 'num16', 'num17',
#        'num18', 'num19', 'num20', 'num21', 'num22', 'num23', 'num24', 'num25',
#        'num26', 'num27', 'num28', 'num29', 'num30', 'num31', 'num32', 'num33',
#        'num34', 'num35', 'num36', 'num37', 'num38', 'num39', 'num40', 'num41',
#        'num42', 'num43', 'num44', 'num45', 'num46', 'num47', 'num48', 'num49',
#        'num50', 'num51', 'num52', 'num53', 'num54', 'num55', 'num56', 'num57',
#        'num58', 'num59', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9', 'cat10', 'cat11', 'cat12', 'cat13', 'cat14', 'cat15', 'cat16',
#        'cat17', 'cat18', 'cat19', 'cat20', 'cat21', 'cat22', 'cat23', 'cat24',
#        'cat25', 'cat26', 'cat1_A', 'cat1_B', 'cat1_C', 'cat1_D', 'cat1_E',
#        'cat2_G', 'cat2_H', 'cat2_I', 'cat2_J', 'cat2_A', 'cat2_B', 'cat2_C',
#        'cat2_D', 'cat2_E', 'cat2_F', 'cat2_K', 'cat2_L'],
#       dtype='object')
# (77, 100)

# %%
yhat = mod.predict(x_holdout)
yhat
# Out:
# array([20.00851275, 20.05014019, 20.00851275, 20.05014019, 20.05321981,
#        20.05014019, 20.00851275, 20.09484725, 20.00851275, 20.05014019,
#        20.05321981, 20.05321981, 20.00851275, 20.05014019, 20.00851275,
#        20.00851275, 20.05321981, 20.05321981, 20.09484725, 20.00851275,
#        20.00851275, 20.00851275, 20.00851275, 20.00851275, 20.05014019,
#        20.05321981, 20.05321981, 20.05321981, 20.00851275, 20.09484725,
#        20.05014019, 20.05014019, 20.00851275, 20.00851275, 20.00851275,
#        20.05321981, 20.00851275, 20.00851275, 20.00851275, 20.00851275,
#        20.05014019, 20.09484725, 20.05321981, 20.09484725, 20.05321981,
#        20.05321981, 20.05321981, 20.00851275, 20.00851275, 20.00851275,
#        20.00851275, 20.05321981, 20.05321981, 20.00851275, 20.05014019,
#        20.00851275, 20.05321981, 20.09484725, 20.09484725, 20.05321981,
#        20.00851275, 20.00851275, 20.00851275, 20.05321981, 20.05321981,
#        20.09484725, 20.05321981, 20.05321981, 20.80911178, 20.93855552,
#        20.16470139, 20.61359749, 19.97536545, 19.69902313, 20.05321981,
#        19.93286368, 19.93286368])

# %%
y_out = pd.Series({'Predictin': yhat})
